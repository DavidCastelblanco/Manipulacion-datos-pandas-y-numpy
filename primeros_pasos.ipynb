# %%
# import pandas as pd
# import numpy as np

# sr = pd.Series([10,9,8,7,6], index = ['a', 'b', 'c', 'd', 'e'])
# dic_data = {'CO':100, 'MX':200, 'AR':300}
# sr_dic = pd.Series(dic_data, index= ['CO', 'MX', 'PE'])

# # sr_dic.isnull()

import pandas as pd
import numpy as np

def run ():

    sr = pd.Series([10,9,8,7,6], index = ['a', 'b', 'c', 'd', 'e'])
    dic_data = {'CO':100, 'MX':200, 'AR':300}
    sr_dic = pd.Series(dic_data, index= ['CO', 'MX', 'PE'])

    print(sr_dic.isnull())
    # print(sr)
    # print (sr.values)
    # print (sr.index)
    # print (sr.shape)
    # print (sr[[0,2,3]])


if __name__=='__main__':
    run()
# Out:
# CO    False
# MX    False
# PE     True
# dtype: bool
